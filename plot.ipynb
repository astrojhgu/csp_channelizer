# %%
import numpy as np
import matplotlib.pylab as plt

# %%
#data1=np.fromfile("result1.bin", dtype=np.complex64).reshape((88*16, -1))
data=np.fromfile("result.bin", dtype=np.complex64).reshape((88*16, -1))

# %%
plt.figure(figsize=(20,20))
plt.plot(10*np.log10(np.sum(np.abs(data)**2, axis=1)[:16]))

# %%
shifted=np.fromfile("shifted.bin", dtype=np.complex64).reshape((88, -1))
shifted
# Out:
# array([[ 270.         +0.j      ,  256.39648   +83.269714j,
#          218.11159  +158.49396j , ..., -157.1786   -219.0591j  ,
#          -82.636665 -256.04135j ,   -0.6014954-269.356j   ],
#        [   0.         +0.j      ,    0.         +0.j      ,
#            0.         +0.j      , ...,    0.         +0.j      ,
#            0.         +0.j      ,    0.         +0.j      ],
#        [   0.         +0.j      ,    0.         +0.j      ,
#            0.         +0.j      , ...,    0.         +0.j      ,
#            0.         +0.j      ,    0.         +0.j      ],
#        ...,
#        [   0.         +0.j      ,    0.         +0.j      ,
#            0.         +0.j      , ...,    0.         +0.j      ,
#            0.         +0.j      ,    0.         +0.j      ],
#        [   0.         +0.j      ,    0.         +0.j      ,
#            0.         +0.j      , ...,    0.         +0.j      ,
#            0.         +0.j      ,    0.         +0.j      ],
#        [   0.         +0.j      ,    0.         +0.j      ,
#            0.         +0.j      , ...,    0.         +0.j      ,
#            0.         +0.j      ,    0.         +0.j      ]],
#       dtype=complex64)

# %%
plt.plot(np.real(shifted[0,:64]))

# %%
plt.plot(np.imag(shifted[0,:1024]))

# %%
plt.plot(x[:,1])

# %%
spec=np.fromfile("spec.bin", dtype=np.float32).reshape((-1, 88*16))
spec.shape
# Out:
# (1101, 1408)

# %%
for i in range(16):
    plt.plot(np.log10(spec[:, i])*10)
