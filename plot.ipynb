# %%
import numpy as np
import matplotlib.pylab as plt

# %%
data=np.fromfile("a.bin", dtype=np.complex64).reshape((8, -1))

# %%
plt.plot(np.abs(data[:,0]))

# %%
data=np.fromfile("result.bin", dtype=np.complex64).reshape((88*32, -1))

# %%
plt.figure(figsize=(20,20))
for i in range(15, 25):
    plt.plot(np.abs(data[:80,i]))

# %%
data0=np.fromfile("data.bin", dtype=np.complex64).reshape((88,-1))
data1=np.fromfile("pfb.bin", dtype=np.complex64).reshape((88,-1))
coeffs=np.fromfile("coeff.bin", dtype=np.float32)

# %%
n=65536-8
np.sum((data0[0, n*16:128+n*16]*coeffs).reshape((8,-1)), axis=0)
# Out:
# array([37746816.+0.j, 37746852.+0.j, 37746888.+0.j, 37746924.+0.j,
#        37746960.+0.j, 37746996.+0.j, 37747032.+0.j, 37747068.+0.j,
#        37747104.+0.j, 37747140.+0.j, 37747176.+0.j, 37747212.+0.j,
#        37747248.+0.j, 37747284.+0.j, 37747320.+0.j, 37747356.+0.j],
#       dtype=complex64)

# %%
data1[1, n*16:16+n*16]
# Out:
# array([37746816.+0.j, 37746852.+0.j, 37746888.+0.j, 37746924.+0.j,
#        37746960.+0.j, 37746996.+0.j, 37747032.+0.j, 37747068.+0.j,
#        37747104.+0.j, 37747140.+0.j, 37747176.+0.j, 37747212.+0.j,
#        37747248.+0.j, 37747284.+0.j, 37747320.+0.j, 37747356.+0.j],
#       dtype=complex64)

# %%
data1[-1,-128:]
# Out:
# array([37746816.+0.j, 37746852.+0.j, 37746888.+0.j, 37746924.+0.j,
#        37746960.+0.j, 37746996.+0.j, 37747032.+0.j, 37747068.+0.j,
#        37747104.+0.j, 37747140.+0.j, 37747176.+0.j, 37747212.+0.j,
#        37747248.+0.j, 37747284.+0.j, 37747320.+0.j, 37747356.+0.j,
#        29358784.+0.j, 29358812.+0.j, 29358840.+0.j, 29358868.+0.j,
#        29358896.+0.j, 29358924.+0.j, 29358952.+0.j, 29358980.+0.j,
#        29359008.+0.j, 29359036.+0.j, 29359064.+0.j, 29359092.+0.j,
#        29359120.+0.j, 29359148.+0.j, 29359176.+0.j, 29359204.+0.j,
#        22019200.+0.j, 22019220.+0.j, 22019242.+0.j, 22019264.+0.j,
#        22019284.+0.j, 22019304.+0.j, 22019326.+0.j, 22019348.+0.j,
#        22019368.+0.j, 22019388.+0.j, 22019410.+0.j, 22019432.+0.j,
#        22019452.+0.j, 22019472.+0.j, 22019494.+0.j, 22019516.+0.j,
#        15728080.+0.j, 15728095.+0.j, 15728110.+0.j, 15728125.+0.j,
#        15728140.+0.j, 15728155.+0.j, 15728170.+0.j, 15728185.+0.j,
# ...

# %%
37747248-1048575
# Out:
# 36698673
